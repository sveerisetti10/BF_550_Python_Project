# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import skbio 
import seaborn as sns
sns.set()
import scipy.stats as stats
# PCA imports
from sklearn.decomposition import PCA

# %%
#We can read in our dataframe using Pandas. 
data = pd.read_csv('/Users/sveerisetti/Desktop/Boston_University/Semester2/BF_550_Python/Final_Project/Bee_data/CSV_PCoA_Data/Weighted_PCOA_Data.csv')
data


#We want to make our rownames equivalent to the Gene Name so that we can pass the dataframe through the PCA value function.
data2 = data.set_index("Gene")
data2
# Out:
#            HC1-D5   HC10-D5   HC11-D5   HC12-D3   HC12-D5   HC12-H0   HC13-D7  \
# Gene
# HC1-D5   0.000000  0.188244  0.079845  0.295045  0.067188  0.391929  0.182172
# HC10-D5  0.188244  0.000000  0.206592  0.338805  0.223670  0.385605  0.176790
# HC11-D5  0.079845  0.206592  0.000000  0.344207  0.122709  0.340266  0.217710
# HC12-D3  0.295045  0.338805  0.344207  0.000000  0.243916  0.601242  0.253865
# HC12-D5  0.067188  0.223670  0.122709  0.243916  0.000000  0.410460  0.190012
# ...           ...       ...       ...       ...       ...       ...       ...
# HT10-D3  0.556025  0.569692  0.586979  0.399413  0.567893  0.852763  0.463301
# HT13-D3  0.506396  0.548459  0.523504  0.425047  0.516115  0.734266  0.444924
# HT5-D5   0.380624  0.401896  0.416899  0.362907  0.390979  0.675606  0.294117
# HT9-D7   0.311933  0.373408  0.314079  0.469599  0.324882  0.515854  0.285161
# HT14-D3  0.300977  0.428990  0.287055  0.528199  0.321104  0.487998  0.376902
#
#           HC14-D3   HC14-H0    HC2-D7  ...   HT13-D5    HT1-D3    HT6-D7  \
# Gene                                   ...
# HC1-D5   0.104282  0.139373  0.212252  ...  0.416482  0.356746  0.260768
# HC10-D5  0.261012  0.277749  0.292085  ...  0.461527  0.367263  0.301034
# HC11-D5  0.065117  0.093578  0.263928  ...  0.458953  0.383855  0.298345
# HC12-D3  0.362506  0.394475  0.112339  ...  0.261204  0.199224  0.212601
# HC12-D5  0.134973  0.170387  0.172662  ...  0.432041  0.381651  0.273664
# ...           ...       ...       ...  ...       ...       ...       ...
# HT10-D3  0.601589  0.617669  0.469122  ...  0.188672  0.269082  0.339820
# HT13-D3  0.526157  0.527736  0.467833  ...  0.301244  0.339856  0.376870
# HT5-D5   0.420515  0.437024  0.349856  ...  0.317388  0.325540  0.243339
# HT9-D7   0.308852  0.303748  0.393564  ...  0.469293  0.487159  0.310532
# HT14-D3  0.282554  0.288680  0.457684  ...  0.578320  0.582404  0.421659
#
#           HT13-D7    HT8-H0   HT10-D3   HT13-D3    HT5-D5    HT9-D7   HT14-D3
# Gene
# HC1-D5   0.211171  0.160214  0.556025  0.506396  0.380624  0.311933  0.300977
# HC10-D5  0.298350  0.243690  0.569692  0.548459  0.401896  0.373408  0.428990
# HC11-D5  0.244095  0.100239  0.586979  0.523504  0.416899  0.314079  0.287055
# HC12-D3  0.387809  0.429974  0.399413  0.425047  0.362907  0.469599  0.528199
# HC12-D5  0.248144  0.202199  0.567893  0.516115  0.390979  0.324882  0.321104
# ...           ...       ...       ...       ...       ...       ...       ...
# HT10-D3  0.546753  0.638538  0.000000  0.371816  0.262491  0.603640  0.712621
# HT13-D3  0.449012  0.539541  0.371816  0.000000  0.431659  0.388413  0.530686
# HT5-D5   0.373134  0.463350  0.262491  0.431659  0.000000  0.432816  0.531674
# HT9-D7   0.202883  0.308370  0.603640  0.388413  0.432816  0.000000  0.197709
# HT14-D3  0.301632  0.312391  0.712621  0.530686  0.531674  0.197709  0.000000
#
# [125 rows x 125 columns]

# %%
#Next we want to find out the Principal Component Analysis
pcoa_values = skbio.stats.ordination.pcoa(data2.values)
pc_plot_coordinates = pcoa_values.samples[['PC1', 'PC2']]

pc_plot_coordinates
# Out:
# /Users/sveerisetti/opt/anaconda3/lib/python3.9/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.18571351697033187 and the largest is 4.512473776139555.
#           PC1       PC2
# 0   -0.081431 -0.036121
# 1   -0.089060 -0.065719
# 2   -0.132187 -0.012832
# 3    0.182337 -0.123827
# 4   -0.062551 -0.096106
# ..        ...       ...
# 120  0.419240  0.134958
# 121  0.255155  0.241035
# 122  0.171459  0.079747
# 123 -0.067016  0.174805
# 124 -0.165884  0.096000
#
# [125 rows x 2 columns]

# %%
# Here we create a list of our conditions so that we can group our data when we plot 
conditions = [
    (data['Gene'].str.contains("HC") & data['Gene'].str.contains("D3")),
    (data['Gene'].str.contains("HC") & data['Gene'].str.contains("D5")),
    (data['Gene'].str.contains("HC") & data['Gene'].str.contains("D7")),
    (data['Gene'].str.contains("HT") & data['Gene'].str.contains('D3')), 
    (data['Gene'].str.contains("HT") & data['Gene'].str.contains('D5')),
    (data['Gene'].str.contains("HT") & data['Gene'].str.contains('D7')),
    (data['Gene'].str.contains("HT") & data['Gene'].str.contains('H0')),
    (data['Gene'].str.contains("HC") & data['Gene'].str.contains('H0'))
    
    ]

# create a list of the values we want to assign for each condition
values = ["Control- Post Day 3", "Control- Post Day 5", "Control- Post Day 7", "Treatment- Post Day 3", "Treatment- Post Day 5", "Treatment- Post Day 7",
         'Treatment- Post Day 0', 'Control- Post Day 0']

# create a new column and use np.select to assign values to it using our lists as arguments
data['Group'] = np.select(conditions, values)

#Now we need to extract the Group column and join it with the data df, which has all of the PCA coordinates 
extracted_col = data["Group"]
extracted_col

pc_plot_coordinates['Group'] = data['Group'].values
pc_plot_coordinates
# Out:
# /var/folders/qj/q80cnm5j5mgd448km33pk9vw0000gn/T/ipykernel_18187/4144544191.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           PC1       PC2                  Group
# 0   -0.081431 -0.036121    Control- Post Day 5
# 1   -0.089060 -0.065719    Control- Post Day 5
# 2   -0.132187 -0.012832    Control- Post Day 5
# 3    0.182337 -0.123827    Control- Post Day 3
# 4   -0.062551 -0.096106    Control- Post Day 5
# ..        ...       ...                    ...
# 120  0.419240  0.134958  Treatment- Post Day 3
# 121  0.255155  0.241035  Treatment- Post Day 3
# 122  0.171459  0.079747  Treatment- Post Day 5
# 123 -0.067016  0.174805  Treatment- Post Day 7
# 124 -0.165884  0.096000  Treatment- Post Day 3
#
# [125 rows x 3 columns]

# %%
# Here we create a list of our conditions so that we can group our data when we plot 
conditions2 = [
    (data['Gene'].str.contains("HC") | data['Gene'].str.contains('P')),
    (data['Gene'].str.contains("HT") )  
    ]

# create a list of the values we want to assign for each condition
values2 = ['Control', "Treated"]

# create a new column and use np.select to assign values to it using our lists as arguments
data['Variable'] = np.select(conditions2, values2)

#Now we need to extract the Group column and join it with the data df, which has all of the PCA coordinates 
extracted_col2 = data["Variable"]
extracted_col2

pc_plot_coordinates['Variable'] = data['Variable'].values
pc_plot_coordinates

pc_plot_coordinates.to_csv('/Users/sveerisetti/Desktop/mom.csv')
# Out:
# /var/folders/qj/q80cnm5j5mgd448km33pk9vw0000gn/T/ipykernel_18187/3082713671.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#sns.rcParams["figure.figsize"] = [10.50, 10.50]
#sns.rcParams["figure.autolayout"] = True
#yes = sns.scatterplot(pc_plot_coordinates['PC1'], pc_plot_coordinates['PC2'], data = pc_plot_coordinates, hue = "Group" )
figure = sns.lmplot('PC1', 'PC2', data = pc_plot_coordinates, hue = 'Group', markers = ['^', '>', '<', 'p', 'v', 'o', 'h', 'H', '*'], ci = None, fit_reg = False)

figure.set(xlim=(-0.4, 0.5))
figure.set(ylim=(-0.3, 0.3))

# %%
figure = ggplot(pc_plot_coordinates, aes(x= 'PC1', y= 'PC2', 
                                          color = 'Group')) + geom_point()
